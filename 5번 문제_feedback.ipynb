# %% [markdown]
# # 5-1 군집화
#
#
# ## Q1
#
# 다음 중 K-Means 클러스터링 모델이 보일 수 있는 결과에 가장 가까운 것은 무엇인가요?

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1) a
#
# 2) b
#
# 3) c
#
# 4) d

# %% [markdown]
# [검수자]
#
# - 정답 및 해설서 없음, 추가 필요

# %% [markdown]
# ## Q2
#
# 계층적 군집화에 대한 설명으로 적합하지 않은 것은 무엇인가요?
#
# 1) 단일 연결(single linkage) 방식은 두 군집에 속한 데이터 포인트 중 거리가 가장 가까운 것을 우선으로 병합합니다.
#
# 2) 군집의 수는 병합 과정 이전에 정해야 합니다.
#
# 3) 워드 연결 (ward linkage) 는 두 군집의 결합이 분산의 증가량이 최소화하는 것을 우선으로 병합합니다.
#
# 4) 연산량이 다른 군집화 모델에 비해 큽니다.
#
# <font color='red'> 정답 2: 병합 과정을 통해 계층 구조를 완료한 후에도 가능합니다.</font>
#
#
# ## Q3
#
# 군집화 모델에 대한 설명으로 적합한 것은 무엇인가요?
#
# 1) 혼합 가우시안 모델의 학습은 보통 경사 하강법을 사용합니다.
#
# 2) DBSCAN 은 밀도 기반의 학습법으로 군집의 수를 정의할 필요가 있습니다.
#
# 3) k-medoid 군집화는 연산량이 k-mean 보다는 더 크지만 k-means 보다 더 좋은 성능이 보장 됩니다.
#
# 4) k-medoid, k-mean, 가우시안 혼합 모델, DBSCAN는 모델의 초기 상태에 따라 다른 결과가 나오지만, 계층적 군집하는 동일한 결과가 보장됩니다.
#
#
# <font color='red'> 정답 4
#
#     1) EM 알고리즘입니다.
#
#     2) 군집수는 학습을 통해 결정됩니다.
#
#
# </font>

# %% [markdown]
# [검수자]
#
# - 의미전달에 혼동을 줄 수 있으므로 다음 문장 중 볼드체 부분 수정 필요
#
# > 4) k-medoid, k-mean, 가우시안 혼합 모델, DBSCAN는 모델의 초기 상태에 따라 다른 결과가 나오지만, 계층적 군집**하는(화는, 또는 계층적 군집 분석 모델은)** 동일한 결과가 보장됩니다.
#
# - 보충 설명
#
# > 3) k-medoid 군집화는 연산량이 k-mean 보다는 더 크지만 k-means 보다 더 좋은 성능이 보장 됩니다.
#
# => 항상 더 좋은 성능이 보장되는 것은 아니며, k-medoids는 K-Means에 비해 이상치에 로버스트(robust)한 성능을 보임

# %% [markdown]
# # 5-2 차원 축소
#
#
# ## Q1
#
# 데이터에 주성분분석(Principal Component Analysis; PCA)을 적용한 뒤 새로운 모델을 생성하려고 합니다. 이 때 새로운 모델이 사용하는 입력에 대한 설명으로 틀린 것은 무엇인가요?
#
# 1) 일반적으로 설명하는 분산의 양이 큰 성분을 우선적으로 선택하여 새로운 모델이 전달합니다.
#
# 2) 선택과정에서 제외된 성분들이 가진 분산만큼 설명력이 사라집니다.
#
# 3) 선택한 주성분의 수가 많아질 수록 새로운 모델의 분산이 낮아지는 경향이 있습니다.
#
# 4) 모든 변수들이 서로 완전히 독립이라면 주성분분석의 효과를 전혀 기대할 수 없습니다.
#
# <font color='red'> 정답 3: 분산은 높아지는 경향이 있게 됩니다.</font>

# %% [markdown]
# [검수자]
#
# - 볼드체로 표시한 단어의 조사 수정 필요
#
# > 1) 일반적으로 설명하는 분산의 양이 큰 성분을 우선적으로 선택하여 새로운 **모델이(에)** 전달합니다.

# %% [markdown]
# ## Q2
#
# 차원 축소 모델에 대한 설명으로 적합한 것은 무엇인가요?
#
# 1) Compact SVD 방식으로 차원을 축소하면, 데이터의 손실이 발생합니다.
#
# 2) 다차원 척도법(MDS)에서 차원 축소의 목표점은 원래 데이터의 거리 정보와 유지하는 것입니다.
#
# 3) 부분 최소 제곱 회귀(PLS)는 k 차원의 입력 데이터와 범주형 변수형 y와의 일원분산분석(ANOVA)의 pvalue가 최대가 되는 선형 변환을 찾아 차원을 축소합니다.
#
# 4) M개의 클래스를 변수에 대해 N개의 변수를 LDA(Linear Discriminant Analysis) 방법을 통해 축소할 때, 최대 성분 수는 N - 1 입니다.
#
#
# <font color='red'> 정답 2 </font>
#
# <font color='red'>1) Compact SVD 는 손실이 발생하지 않은 수준까지 rank를 줄입니다. </font>
#
# <font color='red'>3) k차원의 입력 데이터 X 와 수치형 대상 변수 y 에서, y와의 공분산이 최대가 되는 X의 선형 변환을 찾아 차원을 축소합니다.</font>
#
# <font color='red'>4) Linear Discrimanant Analysis의 성분수는 대상 변수의 클래스의 수 - 1 즉 M - 1 입니다.</font>

# %% [markdown]
# ## Q3
#
# 다음 차원 축소 모델에 대한 설명중 옳은 것은 무엇인가요?
#
# 1) 주성분 분석(Principal compoenent analysis PCA)의 결과는 특이값 분해를 활용하여 얻을 수 있습니다.
#
# 2) t-SNE의 손실 함수는 크로스 엔트로피(Cross Entropy) 입니다.
#
# 3) Truncated SVD를 통해 차원을 축소하면 원래의 데이터와 손실 없이 복원할 수 있습니다.
#
# 4) 다차원 척도법(MDS)은 데이터 포인트 사이의 유사도를 구하여 확률 분포로 나타내고, 확률 분포가 유사항 방향으로 차원을 축소합니다.
#
# <font color='red'> 정답 1</font>
#
# <font color='red'> 2) KL Divergence 입니다.</font>
#
# <font color='red'> 4) t-SNE에 대한 설명입니다.</font>

# %% [markdown]
# [검수자]
#
# - 오타 수정 필요
#
# > Principal **compo~~e~~nent** analysis
#
# > 4) 다차원 척도법(MDS)은 데이터 포인트 사이의 유사도를 구하여 확률 분포로 나타내고, 확률 분포가 **유사항(한)** 방향으로 차원을 축소합니다.

# %% [markdown]
# # 5-3 이상치 탐색
#
#
# ## Q1
#
# 다음 중 이상치 탐색에 사용될 수 있는 아이디어와 가장 거리가 먼 것은 무엇인가요?
#
#
# 1) PCA의 일정 수준이상의 성분을 선택한 후, 다시 역변환을 했을 때 원래 데이터의 차이가 큰 데이터 포인트를 선택합니다.
#
# 2) 각 데이터 포인트의 주변 영역의 데이터 포인트의 밀도를 기준으로 낮은 데이터 포인트를 선택합니다.
#
# 3) 데이터셋을 임의 분기점을 만들어 데이터를 나무 구조로 나누어갈 때, 각 데이터 포인트가 더 이상 분기를 만들 수 없는 완전 분리된 상태가 되기 까지의 깊이가 큰 데이터 포인트를 선택합니다.
#
# 4) 제 1사분위수 Q1 와 3사분위수 Q3 를 구하여 IQR(Interquantile)을 구하여 이를 기반으로, 정상치의 하한과 상항을 구하여 정상 범위를 벋어나면 이상치로 선택합니다.
#
# <font color='red'> 정답 3번: 깊이가 작을 수록 이상치일 가능성이 높습니다.</font>
#
#
# ## Q2
#
# Local Outlier Factor에 대한 설명으로 적합하지 않은 것은 무엇인가요?
#
# 1) 데이터의 분포나 밀도에 대한 가정을 하지 않기 때문에 다양한 유형의 데이터에 적용할 수 있습니다.
#
# 2) 데이터의 차원을 높일 수록 효과적인 이상치 판별 결과를 얻을 수 있습니다.
#
# 3) 모든 데이터를 고려하지 않고, 해당 포인트의 주변 데이터만을 이용하여 탐지합니다.
#
# 4) 데이터 포인트 k에 대해서 LOF(k) < 1 이라는 것은 이웃보다 밀도가 높다는 것을 의미합니다.
#
# <font color='red'> 정답 2: LOF는 거리 기반의 방법이라, 차원의 저주(Curse of Dimensionality) 문제에 취약합니다. 차원이 높을 수록 효과적인 결과를 얻기 위해서는 더 많은 데이터가 요구되어 효과성이 떨어집니다.</font>
#
#
# ## Q3
#
# Isolation Forest에 대한 설명으로 적합한 것은 무엇인가요?
#
# 1) Isolation Forest iTree의 결과가 불안정 하여, Boosting 방법을 응용하여 이상치 여부를 나타내는 점수의 신뢰성을 높입니다.
#
# 2) Isolation Forest 는 범주형 변수를 지원하지 않습니다.
#
# 3) 변수간에 서로 독립이라는 가정이 필요합니다.
#
# 4) 고차원 데이터에서의 성능 저하가 상대적으로 적은 편입니다.
#
# <font color='red'> 정답 4번 </font>
#
# <font color='red'> 1) Boosting이 아니라  Bagging 입니다. </font>
#
# <font color='red'> 3) 데이터에 대한 가정이 필요없습니다.</font>

# %% [markdown]
# [검수자]
#
# - 조사 수정 필요
#
# > 1) Isolation Forest iTree의 결과가 불안정 하여, Boosting 방법을 응용하여 이상치 여부를 나타내는 **점수의** 신뢰성을 높입니다.
