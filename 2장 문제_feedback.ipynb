# %% [markdown]
# # 2-1 확률 개론
#
# ## Q1
#
# 독감 진단 키트는 독감에 걸린 사람을 양성 결과를 낼 확률은 90%입니다.
#
# 독감이 아닌 사람이 양성 결과를 받을 확률은 3%입니다.
#
# 도시 전체 인구 중 10%가 독감에 감염되었다고 알려져 있습니다.
#
# 어떤 사람이 독감 진단 키트로 양성 결과를 받았을 경우, 실제로 독감에 감염되었을 확률을 구합니다.
#
# 1) 약 75.9%
#
# 2) 약 76.9%
#
# 3) 약 77.9%
#
# 4) 약 78.9%
#
# <font color='red'>정답 2번: $\text{P(독감 O | 키트 ＋)} = \frac{{P(\text{키트 ＋}| \text{독감 O})P(\text{독감 O})}}{P(\text{키트 ＋}|\text{독감 O})P(\text{독감 O}) + P(\text{키트 ＋}|\text{독감 X})P(\text{독감 X})}$ </font>
#
# <font color='red'>$ = \frac{0.9 × 0.1}{0.9 × 0.1 + 0.03 × 0.9} ≈ 0.769$</font>
#
#
# ## Q2
#
# 다음 중 사건 A, B가 독립일 때, 성립하지 않은 것은 무엇인가요?
#
# 1) $P(A|B) = P(A)$
#
# 2) $P(B|A) = P(B)$
#
# 3) $P(A \cup B) = P(A) + P(B)$
#
# 4) $P(A \cap B) = P(A)P(B)$
#
# <font color='red'>정답 3번: 3이 성립하려면 $P(A \cap B) = 0$ 이어야 하지만 A, B가 독립이라고 $P(A \cap B) = 0$을 의미하는 것은 아닙니다.</font>
#
# ## Q3
#
# 사건 A, B가 C 조건이 주어진다면, 서로 독립이 될 경우 참이 되는 것을 모두 고른 것은 무엇입니까?
#
#   (ㄱ) $P(A|B,C) = P(A|C)$
#
#   (ㄴ) $P(B|A,C) = P(B|C)$
#
#   (ㄷ) $P(A,B|C) = P(A|C)P(B|C)$
#
# 1) (ㄱ)
#
# 2) (ㄱ), (ㄴ)
#
# 3) (ㄱ), (ㄴ), (ㄷ)
#
# 4) 모두 거짓입니다.
#
# <font color='red'> 정답 4 번: A, B의 C에 대한 조건부 독립을 의미하며, (ㄱ), (ㄴ)은 조건부 독립의 정의이며,  $P(A,B|C) = \frac{P(A,B,C)}{P(C)}=P(A|B,C)P(B|C)=P(A|B)P(B|C)$</font>

# %% [markdown]
# # 2-2 확률 분포
#
# ## Q1
#
# 어떤 도시의 택시는 시간 당 평균 5대의 호출 요청을 받습니다. 이 때, 시간 당 3대 이상의 호출을 받을 확률을 구해봅니다. 아래 확률 밀도 함수를 응용해 보세요.
#
# $p(x)=\frac{e^{-\lambda}(\lambda)^x}{x!}$
#
#
# 1) $\frac{e^{-3}3^5}{3!}$
#
# 2) $\frac{e^{-5}5^3}{3!}$
#
# 3) $\sum_{x=0}^3\frac{e^{-5}5^x}{x!}$
#
# 4) $1 - \sum_{x=0}^2\frac{e^{-5}5^i}{x!}$
#
# <font color='red'> 정답 4 번: P(3 대에서 무한대 까지) = 1 - P(0대에서 2대까지의 확률) 입니다</font>

# %% [markdown]
# [검수자]
#
# - 수식 수정 필요
#
#     > 4) $1 - \sum_{x=0}^2\frac{e^{-5}5^i}{x!}$
#
#     =>
#
#     > 4) $1 - \sum_{x=0}^2\frac{e^{-5}5^x}{x!}$

# %% [markdown]
# ## Q2
#
# 수학 시험의 난이도를 측정하기 위해 25 명의 학생들을 선택했으며, 이들 학생의 평균 점수는 75점이고, 표준 편차는 8점입니다.
#
# 수학 시험 성적은 정규 분포를 따르고 각 학생들의 성적이 독립이라고 가정할 때,
#
# 수학 시험 모평균의 95% 신뢰구간을 계산한 결과는 다음 중 무엇인가요?
#
#
# $z_{p}$: 표준정규분포의 **상위** p 지점의 값,
#
# $t_{p, df}$: 자유도가 df인 t 분포의 **상위** p지점의 값
#
# 1) $75 - z_{0.05}\frac{8}{\sqrt{25}} \le \text{수학 시험 모평균} \le 75 + z_{0.05}\frac{8}{\sqrt{25}}$
#
# 2) $75 - z_{0.025}\frac{8}{\sqrt{25}} \le \text{수학 시험 모평균} \le 75 + z_{0.025}\frac{8}{\sqrt{25}}$
#
# 3) $75 - t_{0.05, 24}\frac{8}{\sqrt{25}} \le \text{수학 시험 모평균} \le 75 + t_{0.05, 24}\frac{8}{\sqrt{25}}$
#
# 4) $75 - t_{0.025, 24}\frac{8}{\sqrt{25}} \le \text{수학 시험 모평균} \le 75 + t_{0.025, 24}\frac{8}{\sqrt{25}}$
#
# <font color='red'>정답 4 번: 모집단의 표준편차를 알 수 없으므로,표준정규분포는 사용할 수 없습니다. 모집단은 정규 분포를 따르므로 t 분포를 사용할 수 있습니다. </font>
#
# <font color='red'>표본의 수가 25개 이므로 t분포 통계량의 자유도는 24이고 상위 $\frac{\text{0.05(유의 수준)}}{2}$에 해당하는 위치의 값과 표본표준오차($\frac{8\text{(표본표준편차)}}{\sqrt{25\text{(표본수)}}}$) &nbsp;&nbsp;를 곱한 것 만큼 표본 평균에서 좌우로 떨어진 구간 안이 바로 신뢰구간이 됩니다.</font>
#
#
# ## Q3
#
# 이탈리안 구두 장인이 구두 한 켤례를 만드는 데 걸리는 시간은 20분입니다.
#
# 구두 한 켤례를 만드는 데 걸리는 시간이 t일  확률을 나타내는 분포로 나타낼 때 가장 적합한 분포는 무엇인가요?
#
# 1) 지수 분포
#
#
# 2) 포아송 분포
#
#
# 3) 정규 분포
#
#
# 4) 이항 분포
#
#
# <font color='red'> 정답 1 번: 지수 함수는 사건이 발생하는 시간 간격을 모델하는 것에 사용됩니다.</font>

# %% [markdown]
# # 2-3 가설 검정 개론
#
# ## Q1
#
# 지희 농장 사과는 비바람이 잦은 환경에서 결실을 맺어 수능 수험생 합격 기원용 선물로 인기인 상품입니다.
#
# 지희 농장에서는 엄격한 품질관리로 유명합니다. 나무 하나에서 9개의 사과를 따서 당도가 12 brix 이하이면,
#
# 그 나무의 사과는 전부 아빠가 운영하는 사과잼 공장으로 보냅니다. 9개 사과 표본의 평균이 13 brix이고 표준편차가 0.16 brix일때,
#
# 사과의 당도는 정규 분포를 따르고, 사과는 다른 사과 당도에 영향을 주지 않는다고  가정한다면,
#
# 아래의 가설 검정의 pvalue를 구하기 확률 분포와 검정통계량 그리고 확률 분포의 꼬리 영역의 위치 무엇인가요?
#
# $H_0$: 측정 사과 나무의 사과 당도의 모평균 = 12 brix
#
# $H_1$: 측정 사과 나무의 사과 당도의 모평균 < 12 brix
#
# 1) 표준정규분포, $Z = \frac{13 - 12}{0.4}, 우측 꼬리$
#
# 2) 자유도가 9인 t 분포, $t=\frac{13 - 12}{0.4/\sqrt{9}}, 양측 꼬리$
#
# 3) 표준정규분포, $Z = \frac{13 - 12}{0.4/\sqrt{3}}, 좌측 꼬리$
#
# 4) 자유도가 8인 t 분포, $t=\frac{13 - 12}{0.4/\sqrt{9}}, 좌측 꼬리$
#
# <font color='red'>정답 4 번: 모집단의 분산을 알 수 없지만, 정규 분포를 따른다는 점에서, 자유도가 표본수 - 1 인 t분포를 이용하면 pvalue를 구할 수 있습니다. 이 때 통계량은 $\frac{\text{표본 평균 - 귀무가설의 모평균}}{\text{표본표준편차}/\sqrt{\text{표본수}}}$ </font>

# %% [markdown]
# [검수자]
#
# - 문장 의미 전달을 위해 볼드체로 표기된 부분 수정 필요
#
# > 아래의 가설 검정의 **pvalue를 구하기 확률 분포**와 검정통계량 그리고 확률 분포의 꼬리 영역의 위치 무엇인가요?
#
# - 표본표준편차가 지문에는 0.16 brix로 되어 있음, 1) - 4) 수식에서는 0.4로 되어 있음, 수정 필요

# %% [markdown]
# ## Q2
#
# 아래 테이블은 가설 검정의 결과를 나타냅니다. 제 1종 오류(Type 1 error)와 제 2종 오류((Type 1 error)에 해당하는 위치를 바르게 선택한 것을 고르세요.
#
# |결론\사실|$H_0$가 참 |$H_1$이 참|
# |--------|--------|------|
# |$H_0$이 미기각(not rejected)|(ㄱ)|(ㄴ)|
# |$H_0$이 기각(rejected)|(ㄷ)|(ㄹ)|
#
#
# 1) 제 1종 오류 (Type 1 error) - (ㄷ) , 제 2종 오류 (Type II error) - (ㄴ)
#
# 2) 제 1종 오류 (Type 1 error) - (ㄴ) , 제 2종 오류 (Type II error) - (ㄷ)
#
# 3) 제 1종 오류 (Type 1 error) - (ㄱ) , 제 2종 오류 (Type II error) - (ㄹ)
#
# 4) 제 1종 오류 (Type 1 error) - (ㄹ) , 제 2종 오류 (Type II error) - (ㄱ)
#
# <font color='red'> 정답 1 번: 제 1종 오류(Type 1 error): False Positive. 제 2종 오류(Type 2 error): False Negative</font>

# %% [markdown]
# [검수자]
#
# - 여는 괄호 이중으로 되어 있음, 여는 괄호 하나 삭제
#
# > 제 2종 오류((Type 1 error)에

# %% [markdown]
# ## Q3
#
# 제빵사 재윤이는 식빵을 1.5cm의 두께로 자르는 기계를 구입했습니다.
#
# 오랜 경력의 재윤이는 손의 감촉으로 식빵이 1.5cm 두께가 아닌 것으로 느껴졌습니다.
#
# 이 기계의 표준편차가 0.16cm라고 적혀 있었고, 이를 식빵 두께의 모표준편차라고 가정합니다.
#
# 25개의 식빵 조각으로 식빵 두께의 모평균이 1.5cm 여부를 검정할 기각역을 식빵 표본의 평균으로 바르게 나타낸 것은 무엇입니다. (유의 수준: 5%)
#
# 25개의 표본수는 표본 평균이 정규분포를 따를 만큼 충분하다고 가정합니다.
#
# $z_{p}$: 표준정규분포의 **상위** p 지점의 값,
#
# $t_{p, df}$: 자유도가 df인 t 분포의 **상위** p지점의 값
#
# $\bar{X}$: 25개의 식빵 표본 두께(cm)
#
# 1) $\bar{X} \lt 1.5 - z_{0.025} \frac{0.16}{\sqrt{25}}$ 또는 $\bar{X} \gt 1.5 + z_{0.025} \frac{0.16}{\sqrt{25}}$
#
# 2) $\bar{X} \lt 1.5 - z_{0.05} \frac{0.16}{\sqrt{25}}$ 또는 $\bar{X} \gt 1.5 + z_{0.05} \frac{0.16}{\sqrt{25}}$
#
# 3) $\bar{X} \lt 1.5 - t_{0.025, 24} \frac{0.16}{\sqrt{25}}$ 또는 $\bar{X} \gt 1.5 + t_{0.025, 24} \frac{0.16}{\sqrt{25}}$
#
# 3) $\bar{X} \lt 1.5 - t_{0.05, 24} \frac{0.16}{\sqrt{25}}$ 또는 $\bar{X} \gt 1.5 + t_{0.05, 24} \frac{0.16}{\sqrt{25}}$
#
# <font color='red'> 정답 1 번: 모분산을 알 수 있고, 표본 평균이 정규분포를 따른 다고 가정할 수 있는 점에서, pvalue를 표준 정규 분포를 사용해서 구할 수있습니다. 표본평균의 모표준편차는 $\frac{0.16}{\sqrt{25}}$ 이고 양측 검정이므로 유의 수준의 반에 해당하는 표준정규분포의 상위수를 사용하여 기각역을 구할 수 있습니다. </font>

# %% [markdown]
# # 2-4 가설 검정 - 모평균
#
# ## Q1
#
# 두 집단 X, Y의 모평균이 동일 유무를 t 검정을 사용하여 검정하고자 합니다. 이 때 X, Y에 대한 필수적인 가정을 모두 골라주세요.
#
# (ㄱ) X, Y의 관측치는 서로 독립입니다.
#
# (ㄴ) X, Y의 모집단은 정규 분포를 따릅니다.
#
# (ㄷ) X, Y의 모분산은 서로 같습니다.
#
# 1) (ㄱ)
#
# 2) (ㄱ), (ㄴ)
#
# 3) (ㄱ), (ㄴ), (ㄷ)
#
# 4) 해당 사항 없습니다.
#
# <font color='red'> 정답 2 번: (ㄱ), (ㄴ) 은 필수적이고 모분산이 같은 때와 다를 때를 고려하여 검정을 수행할 수 있습니다.</font>
#
# ## Q2
#
# 표본을 통한 두 모집단 X, Y의 대소 유무를 판단 하기 위한 검정 방법으로 모집단에 대한 어떠한 가정이 필요하지 않은 검정은 무엇입니까?
#
# 1) Mann-Whiteny U 검정
#
# 2) Welch's t-검정
#
# 3) Wilcoxon 부호 순위 검정
#
# 4) 비율적 z-검정
#
# <font color='red'>정답 1 번: Mann Whitney U 검정은 모집단에 대한 어떠한 가정을 필요로 하지 않는 비모수 검정법으로, 두 모집단의 대소관계를 검정합니다.</font>
#
# ## Q3
#
# 정규 분포를 따르는 두 모집단 X, Y의 모평균이 동일 한지를 검정하고자 합니다. 두 모집단의 모분산은 서로 동일하다고 하고, 수집한 표본들은 서로 독립입니다. 이 검정을 수행하기 위해 필요하지 않은 것은 무엇입니까?
#
#
# 1) 두 모집단의 표본들의 평균
#
# 2) 두 모집단의 표본수
#
# 3) 두 모집단의 표본들의 표준편차
#
# 4) 1), 2), 3) 모두 필요합니다.
#
# <font color='red'> 정답 4 번: t 분포를 사용할 수 있고 등분산일 경우에는 통합 분산을 구해야하고 이를 구하기 위해서는 표본수와 표본들의 표준 편차르 구해야 합니다. 또한 표본 평균의 차이가 필요하므로 1), 2), 3) 모두 필요합니다.</font>

# %% [markdown]
# [검수자]
#
# - 지문은 필요하지 않은 것은 무엇입니까?로 묻고 있으나 답은 필요한 것을 찾고 있음, 지문 수정 필요
# - 정답 해설에서 오타 수정 필요

# %% [markdown]
# # 2-5 가설 검정 - 모분산, 정규성
#
# ## Q1
#
# Bartlett 등분산 검정에 대한 설명 (ㄱ), (ㄴ), (ㄷ) 중 옮은 것을 모두 선택한 것은 무엇인가요?
#
# (ㄱ) 2개 이상의 모집단들의 등분산 여부를 검정할 수 있습니다.
#
# (ㄴ) 각 모집단이 정규 분포를 따른다는 가정이 필요합니다.
#
# (ㄷ) 검정통계량은 F 분포를 따릅니다.
#
# 1) (ㄱ), (ㄴ)
#
# 2) (ㄱ), (ㄷ)
#
# 3) (ㄴ), (ㄷ)
#
# 4) (ㄱ), (ㄴ), (ㄷ)
#
# <font color='red'>정답 1 번: Bartlett 검정은 2개 이상의 모집단들의 등분산 여부를 검정할 수 있습니다. 각 모집단은 정규분포를 따른다고 가정합니다. 검정 통계량은 자유도가 모집단 수 - 1 카이제곱분포를 따릅니다.</font>

# %% [markdown]
# ## Q2
#
# 두 모집단의 등분산 여부를 F 분포를 사용하여 검정하고자 합니다. 두 모집단은 정규분포를 따른다고 가정합니다.
#
# 두 모집단에서 표본을 추출하였습니다. 표본은 서로 독립입니다.
#
# 표본에서 수집한 통계량이 아래와 같을 때, 검정통계량과 분자항의 자유도와 분모항의 자유도는 무엇인가요?
#
#
# |구분|표본 분산|표본수|
# |----|------|------|
# |첫 번째 모집단의 표본|15|21|
# |두 번째 모집단의 표본|17|27|
#
#
# 1) 검정 통계량: $\frac{15}{17}$, 분자의 자유도: 21, 분모의 자유도: 27
#
# 2) 검정 통계량: $\frac{15/20}{17/26}$, 분자의 자유도: 20, 분모의 자유도: 26
#
# 3) 검정 통계량: $\frac{15}{17}$, 분자의 자유도: 20, 분모의 자유도: 26
#
# 4) 검정 통계량: $\frac{15/21}{17/27}$, 분자의 자유도: 21, 분모의 자유도: 27
#
# <font color='red'>정답 3 번: 검정 통계량은 \frac{S_1}{S_2} 입니다. 분자를 첫번째 모집단의 표본의 분산을 사용하므로 분자의 자유도는 21 - 1이 됩니다. 분모는 두 번째 모집단의 분산이고 자유도는 27 - 1이 됩니다. </font>

# %% [markdown]
# [검수자]
#
# - 정답 해설에서  \frac{S_1}{S_2} 를 수식으로 인식되도록 code 수정 필요
#
# >  $ \frac{S_1}{S_2} $

# %% [markdown]
# ## Q3
#
# 다음 중 자크-베라(Jarque-Bera) 정규성 검정에서 사용하는 통계량은 무엇인가요?
#
#
# (ㄱ) 왜도 (ㄴ) 첨도 (ㄷ) 중앙값 (ㄹ) 최빈값
#
#
# 1) (ㄱ), (ㄴ)
#
# 2) (ㄱ), (ㄷ)
#
# 3) (ㄴ), (ㄹ)
#
# 4) (ㄷ), (ㄹ)
#
# <font color='red'>정답 1 번: 자크-베라 검정은 검정통계량에 왜도와 첨도가 사용됩니다.</font>

# %% [markdown]
# # 2-6 범주형 자료 분석, 상관 분석
#
# ## Q1
#
# 다음과 같이 성별과 선호 영화 장르 빈도수 테이블이 있습니다.
#
# 귀무가설은 '성별과 선호 영화 장르는 독립이다.'이고 대립가설은 '성별과 선호 영화 장르는 독립이 아니다.' 입니다. 이러한 독립성 검정을 한 결과가 다음과 같습니다.
#
# 이 결과에 대한 분석으로 잘못된 것은 무엇인가요?
#
# 카이제곱 통계량 = 0.926, p-value: 0.630
#
# ||공포|로맨스|액션|
# |---|---|---|---|
# |남|15|25|20|
# |여|10|20|10|
#
# 1) 카이제곱 통계량의 자유도는 2입니다
#
# 2) 유의 수준이 0.05일 때, 성별과 선호 영화는 서로 연관이 있다고 판단할 수 있습니다.
#
# 3) 귀무 가설이 맞다면, 남자이고 공포를 좋아할 확률은 0.15입니다.
#
# 4) 귀무 가설이 맞다면, 여자이고 로맨스를 좋아할 확률은 0.18입니다.
#
# <font color='red'> 정답 2 번: 자유도 = (첫번째 범주수 - 1)×(두번째 범주수 - 1), pvalue가 0.63이므로 독립으로 판단됩니다. 따라서 연관성이 없습니다. 귀무가설이 맞다는 가정은 두 변수는 독립이므로 각각의 교확률은 서로의 곱입니다. $P(남자) = 0.6,P(공포) = 0.25, P(\text{남자} \cap \text{공포}) =0.6 ×0.25=0.15$</font>

# %% [markdown]
# [검수자]
#
# - "여자이고 로맨스를 좋아할 확률" 계산 과정도 정답 해설에 추가하는 것이 좋을 듯함
#
# > $P(여자) = 0.4, P(로맨스) = 0.45, P(\text{여자} \cap \text{로맨스}) =0.4 ×0.45=0.18$

# %% [markdown]
# ## Q2
#
# 피어슨 상관계수에 대한 설명으로 옮지 않은 것은 무엇인가요?
#
# 1) 두 모집단이 정규 분포 따른 다는 가정을 따른다는 가정을 합니다.
#
# 2) 이상치에 민감하지 않습니다.
#
# 3) -1과 1 사이의 범위를 지닙니다.
#
# 4) 스피어만 상관계수는 각 표본의 랭킹에 대한 피어슨 상관계수입니다.
#
# <font color='red'>정답 2 번: 피어슨 상관계수는 이상치에 민감한 편입니다.</font>

# %% [markdown]
# [검수자]
#
# - 정확한 의미 전달을 위해 다음 문장 수정 필요
#
# > 1) 두 모집단이 정규 분포 따른 다는 가정을 따른다는 가정을 합니다.

# %% [markdown]
# ## Q3
#
# 피아노 연주 영재 지희는 OO 음악 콩쿠르 대회에 출전하여, 아쉽게도 입상하지 못했습니다.
#
# 지희 아빠는 이에 심사 위원의 공정성에 대한 의문을 제시했습니다.
#
# 이에 주최측은 아래와 같이 출전자와 심사위원을 익명화하여 점수표를 공개했습니다.
#
#
# | |참가자 A|참가자 B|참가자 C|참가자 D|참가자 E|참가자 F|
# |----|----|----|----|----|----|----|
# |평가자 X|2|4|3|1|5|6|
# |평가자 Y|3|4|1|2|5|6|
#
# 평가자 X와 Y의 일관성을 나타내는 지표로 가장 적합한 것은 무엇입니까?
#
# 1) 피어슨 상관계수
#
# 2) 스피어만 상관계수
#
# 3) 켄달 순위상관계수
#
# 4) 자기 상관계수
#
# <font color='red'>정답 3 번: 두 관측치의 관측값들 간의 모든 경우의 대소비교 결과를 바탕으로 대소 관계의 일치하는 경우 C 불일치할 경우 D 를 기반으로 $\frac{|C| - |D|}{|C| + |D|}$ 상관도를 나타내는 켄달 순위상관계수는 평가자의 일관성을 나타낼 수 있습니다.</font>

# %% [markdown]
# # 2-7 회귀 분석
#
# ## Q1
#
# 다음 중 다중 선형 회귀 분석의 다중공선선 문제와 관련된 내용으로 가장 옳지 않은 것은 무엇인가요?
#
# 1) 다중공선성 문제 존재 여부는 분산팽창계수(VIF)가 지정한 임계값의 초과 여부로 확인할 수 있습니다.
#
# 2) 다중공선성 문제가 클수록 경우 독립 변수들의 회귀 계수의 신뢰 구간의 폭이 좁아 지게 됩니다.
#
# 3) 독립 변수 간의 상관도가 높을 수록 다중공선성 문제를 내포하고 있을 가능성이 높습니다.
#
# 4) 다중공선성 문제를 완화하기 위해 분산팽창계수(VIF)를 기준으로 높은 변수를 우선으로 제거해보는 방법이 있습니다.
#
#
# <font color='red'>정답 2 번: 다중공선성에 의해 회귀 계수의 변동성은 커지고, 이로 인한 신뢰 구간은 넓어집니다. </font>

# %% [markdown]
# [검수자]
#
# - 오타 있음, 수정 필요
#
# > 다중공선선 -> 다중공선성

# %% [markdown]
# ## Q2
#
# 다음 중 선형 회귀 모델에 대한 설명으로 옳지 않은 것은 무엇인 가요?
#
# 1) 총 변동량(SST) = 회귀 변동량(SSR) + 오차 변동량(SSE)은 최소제곱법으로 회귀 계수를 추정한 선형 회귀 모델일 경우 성립합니다.
#
# 2) 수정된 결정 계수는 결정 계수가 종속 변수와 상관 없더라도, 독립 변수가 증가할 수록 무조건 커지는 경향성을 보완해 줍니다.
#
# 3) 이상점은 회귀 계수에 미치는 영향이 큰 데이터 포인트를 의미합니다.
#
# 4) DFBETAS는 데이터 포인트 하나를 제거했을 때 회귀 계수의 변동량을 의미합니다.
#
#
# <font color='red'>정답 3 번: 회귀 계수에 미치는 영향이 큰 데이터 포인트는 영향점이라고 합니다.</font>

# %% [markdown]
# ## Q3
#
# 선형 회귀 분석 결과로 다음과 같은 표를 얻을 수 있었습니다.
#
# 선형 회귀 모델의 계수는 최소제곱법을 사용하여 추정되었습니다.
#
# 다음 분석 결과로 알 수 있는 사항 중에서 잘못된 것은 무엇인가요?
#
# |항목|값|
# |----|----|
# |잔차의 자유도|25|
# |잔차의 제곱합(SSE)|200|
# |회귀 변동량(SSR)|250|
# |회귀 계수1| 계수: 0.02 <br/> 개별 독립 변수 유의성 검정 결과: pvalue = 0.6  |
# |회귀 계수2| 계수: 1.58 <br/> 개별 독립 변수 유의성 검정 결과: pvalue = 0.005  |
# |절편|2.0|
#
# 1) 총 변동량(SST)은 450입니다.
#
# 2) 선형 회귀 모델의 유의성을 위한 F 검정의  검정통계량은 $\frac{250/2}{200/25}$ 이고, 분자의 자유도는 2, 분모의 자유도는 25입니다.
#
# 3) 선형 회귀 모델은 총 28개의 표본으로 추정되었습니다.
#
# 4) 회귀 계수2에 해당하는 독립 변수는 유의 하지 않습니다. (유의 수준: 0.05)
#
# <font color='red'> 정답 4: SST = SSR + SSE, F 통계량 = MSR/MSE, SST의 자유도 = SSR의 자유도 + SSE의 자유도, SSR의 자유도 2, SSE의 자유도 25, SST 자유도 = 표본수 - 1, 개별 독립 변수 유의성 검정의 귀무가설은 회귀계수=0 이다 입니다. 귀무 가설이 기각 되무로 회귀계수는 0이 아니고 이는 유의함을 나타냅니다.</font>

# %% [markdown]
# [검수자]
#
# - 정답 해설에서 오타가 있음, 수정 필요
#
# > 귀무 가설이 기각 되무로 => 귀무 가설이 기각 되므로

# %% [markdown]
# # 2-8 분산 분석
#
# ## Q1
#
# 분산분석의 가정을 만족하는지 확인하고자 합니다. 이 때 적용할만한 검정으로 묶은 것은 무엇입니까?
#
# (ㄱ) Bartlett 등분산 검정
#
# (ㄴ) Shapiro-Wilk 정규성 검정
#
# (ㄷ) 카이제곱 독립성 검정
#
# (ㄹ) Wilcoxon 부호순위 검정
#
#
# 1) (ㄱ), (ㄴ)
#
# 2) (ㄱ), (ㄷ)
#
# 3) (ㄴ), (ㄹ)
#
# 4) (ㄷ), (ㄹ)
#
# <font color='red'> 정답 1: 분산분석의 주요 가정은 각 모집단은 등분산이고 정규분포를 가정하고 있습니다. </font>
#
# ## Q2
#
# 다음 분산분석 결과에서 알 수 있는 내용 중에서 잘못된 것은 무엇인가요?
#
# |요인|자유도|제곱합|평균제곱합|F 통계량|pvalue|
# |----|-----|-----|-----|----|-----|
# |효과|2|\[B\]|\[C\]|\[D\]| 0.08|
# |오차|\[A\]|300|30|-|-|
# |합|12|500|-|-|-|
#
# 1) 관측치 수는 13개 입니다.
#
# 2) 3개의 모집단의 평균은 같지 않다고 결론을 낼 수 있습니다. (유의 수준: 5%)
#
# 3) $A = 10$ 입니다.
#
# 4) $D = \frac{100/2}{300/10}$ 입니다.
#
# <font color='red'> 정답 2: SST의 자유도는 표본수 - 1 = 12, 따라서 표본수는 13개, 분산분석의 귀무가설은 모집단간의 평균은 같다입니다. 귀무 가설을 기각할 수 없으므로 평균은 같다라고 결론을 낼 수 있습니다. SST의 자유도 = SSR의 자유도 + SSE의 자유도, F의 통계량 = MSR/MSE</font>

# %% [markdown]
# [검수자]
#
# - 수식 수정 필요함
#
# > 4) $D = \frac{100/2}{300/10}$ 입니다.
#
# > 참고로 , A=10, B=200, C=200/2=100, D=100/30=$\frac{200/2}{300/10}$
