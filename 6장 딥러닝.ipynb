# %% [markdown]
# # 6-1 퍼셉트론
#
# ## Q1
#
# 다층 퍼셉트론(Multi-Layer Perceptron) 설명 중에 올바르지 않은 것은 무엇인가요?
#
# 1) 활성화 함수와 같이 처리 과정에 비선형성을 부여는 요소가 없으면 단층 퍼셉트론과 차이가 없습니다
#
# 2) 입력층(Input Layer), 여러 개의 은닉층(Hidden Layer), 출력층(Output Layer)으로 구성됩니다.
#
# 3) 다층 퍼셉트론의 출력은 단일 요소만 가능하여, 다중 분류 문제에 적용하기 위해서는 여러 개의 다층 퍼셉트론이 필요합니다.
#
# 4) 입력층에서 출력층의 방향으로 네트워크 형태로 정의된 층의 연결 구조에 따하 순차적으로 연산을 진행하여 결과를 출력합니다.
#
# <font color='red'> 정답 3 번: 소프트맥스를 사용하면 하나의 다층 퍼셉트론으로 분류가 가능합니다.</font>
#
# ## Q2
#
# 다음은 활성화 함수를 2차원 그래프로 시각화한 것입니다. 이에 대한 설명으로 알맞은 것은 무엇인가요?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1) (ㄱ)이 신경망의 층을 늘려감에 따라 지니는 문제점을 (ㄴ)에 의해 해결됩니다.
#
# 2) (ㄱ)은 로짓함수와 동일합니다.
#
# 3) (ㄷ)은 대부분의 출력이 0이되는 유닛이 쉽게 발생하는 문제를 개선하기 위해 (ㄹ)이 만들어졌습니다.
#
# 4) (ㄱ), (ㄷ)에 적합한 가중치의 초기화 방법은 같습니다.
#
# <font color='red'> 정답 3  </font>
#
# <font color='red'> 1) (ㄱ), (ㄴ)은 층이 깊어짐에 따라 동일하게 Vanishing Gradient 문제를 나타냅니다. </font>
#
# <font color='red'> 2) 로지스틱 함수입니다. </font>
#
# <font color='red'> 4) (ㄱ)과 (ㄴ)이 같고 (Xavier Normal, Uniform), (ㄷ), (ㄹ)도 같습니다. (He Normal, Uniform)  </font>
#
#
# ## Q3
#
# 오차 역전파에 대한 설명을 모두 고른 것은 무엇인가요?
#
# (a) 계산된 손실의 그래디언트를 출력층에서 입력층 방향으로 이전 단계의 그래디언트를 바탕으로 다음 단계의 그래디언트를 구합니다.
#
# (b) 오차 역전파는 경사 하강법을 통한 신경망 학습을 위한 알고리즘 입니다.
#
# (c) 체인 법칙(chain rule)을 이용하여 산출합니다.
#
# (d) 심층 신경망에는 적용이 어렵습니다.
#
# 1) (a)
#
# 2) (a), (b)
#
# 3) (a), (b), (c)
#
# 4) (a), (b), (c), (d)
#
#
# <font color='red'> 정답 3: 심층 신경망에 응용의 어려움과는 상관 없습니다. </font>

# %% [markdown]
# # 6-2 인공 신경망
#
# ## Q1
#
# 다음 중 인공 신경망에 관한 설명에 대한 설명으로 가장 옳지 않은 것은 무엇인 가요?
#
# 1) 드롭 아웃(Dropout)은 신경망 모델이 단일 노드에 지나치게 의존적이지 않도록 하고, 여러 번의 임의로 노드을 비활성화(출력을 0으로 만듭니다)시켜 예측을 하고 이를 집계하여 최종 출력값을 만듭니다.
#
# 2) 컨볼루션층의 필터(또는 커널)수는 입력 채널수 × 출력 채널수 이고, 가중치의 수는 필터의 크기와 수에 비례합니다.
#
# 3) 학습 데이터의 손실이 줄어들 수록 검증 데이터에 대한 손실이 증가하면 규제 계수를 늘려 봅니다.
#
# 4) Adam 최적화 알고리즘은 지체 영역을 빠르게 벋어나도록 고안된 모멘텀 방법과 안정적인 학습이 되도록 가중치별 학습율을 맞춰 주는 RMSProp 방법의 장점을 활용했습니다.
#
# <font color='red'> 정답 1: 학습 시에 임의로 비활성화 시킵니다. 예측시에는 드롭 아웃(Dropout)은 동작하지 않습니다.</font>
#
#
# ## Q2
#
# 다음 중 인공 신경망 학습 시 Vanishing Gradient 현상에 대응하기 위한 방법과 거리가 가장 먼 것을 무엇인가요?
#
# 1) LSTM
#
# 2) 배치 정규화 층(Batch Normalization Layer)
#
# 3) Relu 활성화 함수
#
# 4) Pooling Layer
#
# <font color='red'> 정답 4: Pooling Layer는 입력의 크기를 줄이거나 특정 특징을 강조하는 성질을 부여하기 위해 사용합니다.</font>
#
# ## Q3
#
# 신경망 모델링 업무를 지희는 모바일 기기에 호출 구호 "헤이 OO"이라고 하면 반응하여 앱이 구동되게 끔하는 것에 쓰이는 신경망 모델의 개발을 맡았습니다. 음성 신호에서 호출 여부를 주기마다 알려주는 시퀀스 모델에 가장 적합한 구조는 무엇인가요?

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1) (ㄱ)
#
# 2) (ㄴ)
#
# 3) (ㄷ)
#
# 4) (ㄴ)
#
# <font color='red'> 정답 3 번: 시점별 음성 신호와 이전까지의 음성 신호의 정보를 바탕으로 출력(호출 여부)를 판별합니다.</font>
#
# <font color='red'> 1) 어느 시점 이전부터 입력으로 단일 출력을 내주고 있기 때문에 중복해서 입력으로 전달하는 부분도 생기게 되니 ㄷ보다는 비효율적입니다. </font>
#
# <font color='red'> 2) 단일 입력으로 여러 개의 출력은 요구되지 않습니다. </font>
#
# <font color='red'> 4) 일정량의 데이터를 전달한 후에 여러 개의 출력을 요구되지는 않습니다.</font>

# %% [markdown]
# # 6-3 심층 신경망
#
#
# ## Q1
#
# 다음 중 신경망의 층을 늘림에 따라 Vanishing Gradient 현상을 극복하기 위한 방법과 거리가 먼 것은 무엇인가요?
#
# 1) 네트워크 중강에 학습 과정에만 사용하는 보조 분류기(Auxillary Classifier)를 배치합니다.
#
# 2) ReLU 함수와 같이 네트워크가 깊어짐에 따라 각 층의 출력이 커짐에 따른 경사도 소실에 대응할 수 있는 활성화 함수를 사용합니다.
#
# 3) 드롭 아웃을 레이어를 두어 비활성화 된 노드의 만큼의 경사도가 활성화된 노드에 전달되게 하여 극복합니다.
#
# 4) 네트워크의 하위 노드에서 상위 노드로 하위 노드의 출력값을 상위 노드에 전달해주는 잔차 연결을 사용합니다.
#
#
# <font color='red'> 정답 3: 드롭 아웃은 과적합에 대응하기 위한 방법으로 사용됩니다. </font>
#
# ## Q2
#
# 보다 많은 데이터로 학습이 된 신경망의 전체 또는 일부를 가져와서 신경망 모델을 구성하여, 보유하고 있는 데이터만으로 모델을 학습했을 때보다 좋은 일반화 성능을 보이도록 하기 위한 방법을 고른 것은 무엇인 가요?
#
# (a) 전이 학습(Transfer Learning)
#
# (b) 미세 조정(Fine tuning)
#
# (c) Teacher's forcing
#
# (d) 강화 학습(Reinforcement Learning)
#
# 1) (a), (b)
#
# 2) (a), (c)
#
# 3) (b), (c)
#
# 4) (c), (d)
#
# <font color='red'> 정답 1: 전이 학습에서는 가져온 신경망 층은 고정시킨상태에서 보유한 데이터로 학습하고, 미세조정은 모든 층에 대한 학습을 낮은 학습률로 진행합니다.</font>
#
# ## Q3
#
#
# 다음 중 입력층의 내용이 출력층에 내용과 동일하도록 구성된 신경망에 대한 설명을 모두 선택한 것은 무엇인가요?
#
#
# (a) 입력데이터에 노이즈를 주고 노이즈가 없는 상태를 출력하도록 학습시켜, 노이즈 캔슬링에 사용할 수 있습니다.
#
# (b) 인코딩 모델과 디코딩 모델로 나눌 수 있으며, 인코더는 점점 유닛이 줄어 들어 병목층을 형성해가고, 디코더는 점점 원래 데이터 형태에 맞게 층의 유닛을 늘려갑니다.
#
# (c) 생성자(Generator)와 판별자(Discriminator) 모델로 나뉘며 판별자가 맞추면 생성자가 패널티를 반대일 경우 판별자가 패널티를 받는 경쟁구조입니다.
#
# (d) 지도 학습으로 분류 됩니다.
#
# 1) (a)
#
# 2) (a), (b)
#
# 3) (a), (b), (c)
#
# 4) (b), (c), (d)
#
# <font color='red'> 정답 2: 오토 인코더에 대한 설명입니다. 비지도 학습 모델입니다. (c)는 GAN입니다. </font>
